# %%
scenario_folder = 'scenario7/'

# %%
# %matplotlib inline

# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def getRxPacketFile(eNBArray, UEArray, basefolder = ''):
    """ Gets the RxPacketTrace file with
    len(eNBArray) eNBs (radio base station) containers and with
    len(UEArray) UE (user equipment) containers.
    The filename will be for example:
    'RxPacketTrace_e1_e2_e3_u1_u2.txt'
    where e1, e2 and e3 are three eNB containers (representing
    a number of antenas for container), u1 and u2 will be
    user equipment containers, (representing for example 2 rooms
    each with u1 and u2 user equipments respectively)."""
    eNBString = ''
    UEString = ''
    if (len(eNBArray) > 0) and (len(UEArray) > 0):
        for numENB in eNBArray:
            eNBString = eNBString + '_' + str(numENB)
        for numUE in UEArray:
            UEString = UEString + '_' + str(numUE)
    
    
    filename = basefolder + 'RxPacketTrace' + eNBString + UEString + '.txt'
    if os.path.isfile(filename):
#        rxpacketfile = open(filename, "r")
#        return csv.DictReader(rxpacketfile, delimiter='\t')
        with open(filename, "r") as rxpacketfile:
            return pd.read_csv(rxpacketfile, sep='\t', \
                               names=['mode', 'time', 'frame', 'subF', '1stSym', \
                                   'symbol#', 'cellId', 'rnti', 'ccId', 'tbSize', 'mcs', 'rv', \
                                   'SINR(dB)', 'corrupt', 'TBler'], \
                               dtype={'mode': str}, \
                               index_col=1,
                               low_memory=False,
                               #skiprows=0,
                               #header=0,
                               verbose=True,
                               
                              )
    else:
        return None

# %%
def getTcpWindowFile(basefolder = '', UENum=''):
    """ Gets the mmWave-tcp-window-newreno.txt.
    This file contains the following structure:
    TIMESTAMP \t OLD_CWND \t NEW_CWND
    
    where CWND is the tcp congestion window size.
    
    The file doesn't contain a header and is tab separeted
    
    """
    filename = basefolder + 'mmWave-tcp-window-newreno'+UENum+'.txt'
    if os.path.isfile(filename):
#        rxpacketfile = open(filename, "r")
#        return csv.DictReader(rxpacketfile, delimiter='\t')
        with open(filename, "r") as file:
            return pd.read_csv(file, sep='\t', \
                               names=['time', 'old_CWND', 'new_CWND'],
                               index_col=0,
                               low_memory=False,
                               #skiprows=0,
                               #header=0,
                               verbose=True,
                              )
    else:
        return None

# %%
def getTcpRTTFile(basefolder = '', UENum=''):
    """ Gets the mmWave-tcp-rtt-newreno.txt.
    This file contains the following structure:
    TIMESTAMP \t OLD_RTT \t NEW_RTT
    
    where RTT is the round-time-trip.
    
    The file doesn't contain a header and is tab separeted
    
    """
    filename = basefolder + 'mmWave-tcp-rtt-newreno'+UENum+'.txt'
    if os.path.isfile(filename):
        with open(filename, "r") as file:
            return pd.read_csv(file, sep='\t', \
                               names=['time', 'old_RTT', 'new_RTT'],
                               index_col=0,
                               low_memory=False,
                               #skiprows=0,
                               #header=0,
                               verbose=True,
                              )
    else:
        return None

# %%
def getTcpDataFile(basefolder = '', UENum=''):
    """ Gets the mmWave-tcp-rtt-newreno.txt.
    This file contains the following structure:
    TIMESTAMP \t PKG_SIZE
    
    where PKG_SIZE is the size of the received package
    
    The file doesn't contain a header and is tab separeted.
    
    """
    filename = basefolder + 'mmWave-tcp-data-newreno'+UENum+'.txt'
    if os.path.isfile(filename):
        with open(filename, "r") as file:
            return pd.read_csv(file, sep='\t', \
                               names=['time', 'PKG_SIZE'],
                               index_col=0,
                               low_memory=False,
                               #skiprows=0,
                               #header=0,
                               verbose=True,
                              )
    else:
        return None

# %%
os.listdir()
# Out:
# ['paulista_back_tcp',
#  'paulista_far',
#  'test_5sec_3_5_5_5_triangle_shadowing_unset',
#  'Scenario1.ipynb',
#  'paulista',
#  'Scenario9.ipynb',
#  'paulista_double_tcp',
#  '.ipynb_checkpoints',
#  'Scenario8.ipynb',
#  'paulista_tcp',
#  'paulista_back2',
#  'small_grid_test',
#  'paulista_double',
#  'test_10sec_5_40_shadow_off',
#  'paulista_leoncio',
#  'mmWaveTests.ipynb',
#  'mmWaveTests-Paulista_double.ipynb',
#  'test_10sec_2_40_antipodal_shadow_off',
#  'test_5sec_3_5_10_15_triangle_2km_mix_positions_shadowing_off',
#  'test_5sec_3_5_5_5_triangle_shadowing_true',
#  'mmWaveTests-Copy1.ipynb',
#  'Scenario10.ipynb',
#  'test_10sec_1_40_shadow_off',
#  'tcp-building',
#  'Scenario7.ipynb',
#  'buildings',
#  'paulista_back',
#  'test_5sec_3_5_10_15',
#  'paulista_back_4ms',
#  'Scenario4.ipynb',
#  'test_5sec_3_5_10_15_triangle_2km_shadowing_off',
#  'paulista_double_2enb_tcp',
#  'paulista_top',
#  'test_5sec_1_40_noshadow',
#  'paulista_top2',
#  'test_5sec_3_5_10_15_not_shadow',
#  'Scenario11.ipynb',
#  'paulista_4ms',
#  'nohup.out',
#  'test_10sec_5_10_15_shadow_off',
#  'Scenario3.ipynb',
#  'Scenario2.ipynb']

# %%
eNBs = []
UEs = []

rxDF_scenario = getRxPacketFile(eNBs,UEs, scenario_folder)

cwndDF0_scenario = getTcpWindowFile(scenario_folder, '0')
rttDF0_scenario = getTcpRTTFile(scenario_folder, '0')
dataDF0_scenario = getTcpDataFile(scenario_folder, '0')

cwndDF1_scenario = getTcpWindowFile(scenario_folder, '1')
rttDF1_scenario = getTcpRTTFile(scenario_folder, '1')
dataDF1_scenario = getTcpDataFile(scenario_folder, '1')
# Out:
# Tokenization took: 382.23 ms
# Type conversion took: 726.97 ms
# Parser memory cleanup took: 10.26 ms
# Tokenization took: 246.18 ms
# Type conversion took: 136.59 ms
# Parser memory cleanup took: 3.20 ms
# /home/arturao/miniconda3/envs/tf36/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Tokenization took: 305.23 ms
# Type conversion took: 171.62 ms
# Parser memory cleanup took: 4.26 ms
# Tokenization took: 317.42 ms
# Type conversion took: 152.28 ms
# Parser memory cleanup took: 4.58 ms
# Tokenization took: 324.82 ms
# Type conversion took: 114.07 ms
# Parser memory cleanup took: 4.08 ms
# Tokenization took: 309.49 ms
# Type conversion took: 164.56 ms
# Parser memory cleanup took: 4.07 ms
# Tokenization took: 309.61 ms
# Type conversion took: 134.17 ms
# Parser memory cleanup took: 4.35 ms

# %%
if rxDF_scenario is None:
    print('RxPacket file not found!')
else:
    rxDF_scenario = rxDF_scenario[1:].copy() #First line (headers) is skipped
    print(f'RxPacket file loaded as dataframe (eNBs: {eNBs}), (UEs: {UEs})')
    rxDF_scenario.index = rxDF_scenario.index.astype('float')
    rxDF_scenario['SINR(dB)']   = pd.DataFrame(rxDF_scenario['SINR(dB)'], dtype='float')
    rxDF_scenario['rnti']       = pd.DataFrame(rxDF_scenario['rnti'], dtype='int')
    rxDF_scenario['cellId']     = pd.DataFrame(rxDF_scenario['cellId'], dtype='int')
    rxDF_scenario['TBler']      = pd.DataFrame(rxDF_scenario['TBler'], dtype='float')
# Out:
# RxPacket file loaded as dataframe (eNBs: []), (UEs: [])

# %%
rxDF_scenario.tail()
# Out:
#         mode  frame subF 1stSym symbol#  cellId  rnti ccId tbSize mcs rv  \
# time
# 24.9998   DL  24999    8      1       8       1     1    0  14247  28  1
# 24.9998   UL  24999    8      9       1       1     1    0   1776  28  0
# 24.9999   DL  24999    9      1       8       2     1    0  14247  28  0
# 24.9999   UL  24999    9      9       1       2     1    0   1776  28  0
# 25.0000   DL  24999    9      1      19       1     1    0  27588  24  0
#
#          SINR(dB) corrupt  TBler
# time
# 24.9998   22.3326            0.0
# 24.9998   34.3611       0    0.0
# 24.9999   36.1942            0.0
# 24.9999   38.0698       0    0.0
# 25.0000   32.1812            0.0

# %%
rxDF_scenario.index
# Out:
# Float64Index([0.00310832, 0.00310832, 0.00360832, 0.00360832, 0.00400832,
#               0.00400832,  0.0331125,  0.0331125,  0.0336083,  0.0336083,
#               ...
#                  24.9997,    24.9997,    24.9997,    24.9997,    24.9998,
#                  24.9998,    24.9998,    24.9999,    24.9999,       25.0],
#              dtype='float64', name='time', length=754099)

# %%
cwndDF0_scenario.head()
# Out:
#           old_CWND  new_CWND
# time
# 0.122913         0      1400
# 0.145913      1400      2800
# 0.168908      2800      4200
# 0.191908      4200      5600
# 0.214913      5600      7000

# %%
rttDF0_scenario.head()
# Out:
#            old_RTT   new_RTT
# time
# 0.122913  0.000000  0.022000
# 0.145913  0.022000  0.022125
# 0.168908  0.022125  0.022234
# 0.191908  0.022234  0.022330
# 0.214913  0.022330  0.025289

# %%
dataDF0_scenario.head()
# Out:
#           PKG_SIZE
# time
# 0.134437      1400
# 0.157496      1400
# 0.157562      1400
# 0.180496      1400
# 0.180596      1400

# %%
mergedIndexes = np.concatenate((
    rxDF_scenario.index,

    cwndDF0_scenario.index,
    rttDF0_scenario.index,
    dataDF0_scenario.index,

    cwndDF1_scenario.index,
    rttDF1_scenario.index,
    dataDF1_scenario.index
))
mergedIndexes.sort(kind='merge')
mergedIndexes = np.unique(mergedIndexes)
print(mergedIndexes)
# Out:
# [3.10832e-03 3.60832e-03 4.00832e-03 ... 2.49998e+01 2.49999e+01
#  2.50000e+01]

# %%
from collections import defaultdict
d = defaultdict(LabelEncoder)

# %%
integerIndexes = d['time'].fit_transform(mergedIndexes)

# %%
integerIndexes
# Out:
# array([     0,      1,      2, ..., 400375, 400376, 400377])

# %%
rxDF_scenario = rxDF_scenario.set_index(d['time'].transform(rxDF_scenario.index));

cwndDF0_scenario = cwndDF0_scenario.set_index(d['time'].transform(cwndDF0_scenario.index));
rttDF0_scenario = rttDF0_scenario.set_index(d['time'].transform(rttDF0_scenario.index));
dataDF0_scenario = dataDF0_scenario.set_index(d['time'].transform(dataDF0_scenario.index));

cwndDF1_scenario = cwndDF1_scenario.set_index(d['time'].transform(cwndDF1_scenario.index));
rttDF1_scenario = rttDF1_scenario.set_index(d['time'].transform(rttDF1_scenario.index));
dataDF1_scenario = dataDF1_scenario.set_index(d['time'].transform(dataDF1_scenario.index));

# %%
np.unique(rxDF_scenario['cellId'])
# Out:
# array([1, 2])

# %%
print(f"unique rnti\'s: {np.unique(rxDF_scenario['rnti'])}")
print(f"\n\nNumber of unique rnti's: {len(np.unique(rxDF_scenario['rnti']))}")

print("\n\n RNTI 1:")
print(rxDF_scenario[rxDF_scenario['rnti'] == 1])
# Out:
# unique rnti's: [1]
#
#
# Number of unique rnti's: 1
#
#
#  RNTI 1:
#        mode  frame subF 1stSym symbol#  cellId  rnti ccId tbSize mcs rv  \
# 0        DL      3    1      1       1       1     1    0     48   0  0
# 0        DL      3    1      1       1       2     1    0     48   0  0
# 1        UL      3    6      1       1       1     1    0     48   0  0
# 1        UL      3    6      1       1       2     1    0     48   0  0
# 2        DL      4    0      1       1       1     1    0    768  16  0
# 2        DL      4    0      1       1       2     1    0   1640  26  0
# 3        DL     33    1      1       2       1     1    0    100   0  0
# 3        DL     33    1      1       2       2     1    0    100   0  0
# 4        UL     33    6      1       1       1     1    0     48   0  0
# 4        UL     33    6      1       1       2     1    0     48   0  0
# 5        DL     34    0      1       1       1     1    0    768  16  0
# 5        DL     34    0      1       1       2     1    0   1640  26  0
# 6        DL    111    3      1       2       1     1    0    100   0  0
# 6        DL    111    3      1       2       2     1    0    100   0  0
# 7        UL    111    8      1       2       1     1    0    100   0  0
# 7        UL    111    8      1       2       2     1    0    100   0  0
# 8        DL    112    2      1       1       1     1    0   1776  28  0
# 8        DL    112    2      1       1       2     1    0    619  14  0
# 10       DL    134    2      1      22       1     1    0   1131   0  0
# 10       DL    134    2      1      22       2     1    0   1131   0  0
# 11       DL    134    3      1       8       1     1    0    411   0  0
# 11       DL    134    3      1       8       2     1    0    411   0  0
# 13       UL    134    7      1       1       1     1    0     48   0  0
# 13       UL    134    7      1       1       2     1    0     48   0  0
# 14       UL    134    8      1       2       1     1    0    100   0  0
# 14       UL    134    8      1       2       2     1    0    100   0  0
# 15       DL    135    1      1       1       1     1    0   1776  28  0
# 15       DL    135    1      1       1       2     1    0    619  14  0
# 16       UL    139    1      1       1       1     1    0    768  16  0
# 16       UL    139    1      1       1       2     1    0   1776  28  0
# ...     ...    ...  ...    ...     ...     ...   ...  ...    ...  .. ..
# 400368   UL  24999    1      9       1       2     1    0   1776  28  1
# 400368   UL  24999    1     10       1       2     1    0   1640  26  0
# 400369   DL  24999    1      9      14       1     1    0  20328  24  0
# 400369   DL  24999    2      1       8       2     1    0  14247  28  0
# 400369   DL  24999    2      1       8       1     1    0  14247  28  1
# 400370   DL  24999    2      9      11       1     1    0  19592  28  0
# 400370   DL  24999    3      1       8       2     1    0  14247  28  0
# 400370   UL  24999    3      9       1       2     1    0   1640  26  0
# 400370   DL  24999    3      1      10       1     1    0  14520  24  0
# 400371   DL  24999    4      1       8       2     1    0  14247  28  0
# 400371   DL  24999    4      1       8       1     1    0  14247  28  0
# 400371   UL  24999    4      9       1       2     1    0   1776  28  0
# 400371   UL  24999    4      9       1       1     1    0   1776  28  0
# 400372   DL  24999    5      1       8       2     1    0  14247  28  0
# 400373   DL  24999    5      1      15       1     1    0  26719  28  0
# 400373   UL  24999    5     16       1       1     1    0   1776  28  0
# 400373   DL  24999    6      1       8       1     1    0  14247  28  0
# 400374   DL  24999    6      1      15       2     1    0  26719  28  0
# 400374   UL  24999    6     16       1       2     1    0   1776  28  0
# 400374   DL  24999    7      1       8       2     1    0  14247  28  0
# 400374   UL  24999    7      9       1       2     1    0   1776  28  1
# 400374   DL  24999    7      1      10       1     1    0  14520  24  0
# 400374   UL  24999    7     10       1       2     1    0   1640  26  0
# 400374   UL  24999    7     11       1       1     1    0   1776  28  0
# 400375   DL  24999    8      1       8       2     1    0  14247  28  0
# 400375   DL  24999    8      1       8       1     1    0  14247  28  1
# 400375   UL  24999    8      9       1       1     1    0   1776  28  0
# 400376   DL  24999    9      1       8       2     1    0  14247  28  0
# 400376   UL  24999    9      9       1       2     1    0   1776  28  0
# 400377   DL  24999    9      1      19       1     1    0  27588  24  0
#
#         SINR(dB) corrupt         TBler
# 0       11.36520          0.000000e+00
# 0       27.82710          0.000000e+00
# 1       29.38250       0  0.000000e+00
# 1        9.56148       0  0.000000e+00
# 2       11.36520          0.000000e+00
# 2       27.82710          0.000000e+00
# 3       11.36520          0.000000e+00
# 3       27.82710          0.000000e+00
# 4       29.38250       0  0.000000e+00
# 4        9.56148       0  0.000000e+00
# 5       11.36520          0.000000e+00
# 5       27.82710          0.000000e+00
# 6       34.06350          0.000000e+00
# 6       10.59490          0.000000e+00
# 7       14.04880       0  0.000000e+00
# 7       31.91870       0  0.000000e+00
# 8       34.06350          0.000000e+00
# 8       10.59490          0.000000e+00
# 10      34.06350          0.000000e+00
# 10      10.59490          0.000000e+00
# 11      34.06350          0.000000e+00
# 11      10.59490          0.000000e+00
# 13      14.04880       0  0.000000e+00
# 13      31.91870       0  0.000000e+00
# 14      14.04880       0  0.000000e+00
# 14      31.91870       0  0.000000e+00
# 15      34.06350          0.000000e+00
# 15      10.59490          0.000000e+00
# 16      14.04880       0  0.000000e+00
# 16      31.91870       0  1.192890e-06
# ...          ...     ...           ...
# 400368  38.06980       0  0.000000e+00
# 400368  38.06980       0  0.000000e+00
# 400369  34.36110          0.000000e+00
# 400369  36.19420          0.000000e+00
# 400369  22.33260          0.000000e+00
# 400370  34.36110          0.000000e+00
# 400370  36.19420          0.000000e+00
# 400370  38.06980       0  0.000000e+00
# 400370  28.34320          0.000000e+00
# 400371  36.19420          0.000000e+00
# 400371  22.33260          1.000000e+00
# 400371  27.51160       1  1.000000e+00
# 400371  32.55350       0  3.630430e-13
# 400372  36.19420          0.000000e+00
# 400373  31.35180          0.000000e+00
# 400373  34.36110       0  0.000000e+00
# 400373  22.33260          1.000000e+00
# 400374  37.17050          0.000000e+00
# 400374  38.06980       0  0.000000e+00
# 400374  36.19420          0.000000e+00
# 400374  38.06980       0  0.000000e+00
# 400374  28.34320          0.000000e+00
# 400374  38.06980       0  0.000000e+00
# 400374  34.36110       0  0.000000e+00
# 400375  36.19420          0.000000e+00
# 400375  22.33260          0.000000e+00
# 400375  34.36110       0  0.000000e+00
# 400376  36.19420          0.000000e+00
# 400376  38.06980       0  0.000000e+00
# 400377  32.18120          0.000000e+00
#
# [754099 rows x 14 columns]

# %%
cellIdGroupedRBs = rxDF_scenario.groupby(['cellId'])
rntiCellIdGrouped = rxDF_scenario.groupby(['cellId', 'rnti'])
rntiGrouped = rxDF_scenario.groupby(['rnti'])
rntiCellModeGrouped = rxDF_scenario.groupby(['mode', 'cellId', 'rnti'])

# %%
print(len(cellIdGroupedRBs.groups))
print(len(rntiCellIdGrouped.groups))
print(len(rntiGrouped.groups))
print(len(rntiCellModeGrouped.groups))
# Out:
# 2
# 2
# 1
# 4

# %%
fig, (ax, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(15,3))

ax.yaxis.tick_right()


rntiCellModeGrouped.get_group(('DL', 1, 1))['SINR(dB)'].plot(style='.', ax=ax)
rntiCellModeGrouped.get_group(('UL', 1, 1))['SINR(dB)'].plot(style='.', color='darkorange', ax=ax2)

# %%
fig, (ax, ax2) = plt.subplots(ncols=2, sharey=True, figsize=(15,3))

ax.yaxis.tick_right()



rntiCellModeGrouped.get_group(('DL', 2, 1))['SINR(dB)'].plot(style='.', ax=ax)
rntiCellModeGrouped.get_group(('UL', 2, 1))['SINR(dB)'].plot(style='.', color='darkorange', ax=ax2)

# %%
ax = cellIdGroupedRBs.get_group(1)['SINR(dB)'].plot(style='.')
rttDF0_scenario['new_RTT'].plot(secondary_y=True, style='.')

# %%
#for grp in rntiGrouped.groups:
rttDF0_scenario['new_RTT'].plot(style='.')

# %%
#for grp in rntiGrouped.groups:
ax = cellIdGroupedRBs.get_group(2)['SINR(dB)'].plot(style='.')
rttDF1_scenario['new_RTT'].plot(secondary_y=True, style='.')

# %%
#for grp in rntiGrouped.groups:
rttDF1_scenario['new_RTT'].plot(style='.')

# %%
ax = cellIdGroupedRBs.get_group(1)['SINR(dB)'].plot(style='.')
cwndDF0_scenario['new_CWND'].plot(secondary_y=True, style='.')

# %%
cwndDF0_scenario['new_CWND'].plot(style='.')

# %%
ax = cellIdGroupedRBs.get_group(2)['SINR(dB)'].plot(style='.')
cwndDF1_scenario['new_CWND'].plot(secondary_y=True, style='.')

# %%
cwndDF1_scenario['new_CWND'].plot(style='.')

# %%
dataDF0_scenario['PKG_SIZE'].plot(style='.')

# %%
dataDF1_scenario['PKG_SIZE'].plot(style='.')

# %%
cellIdGroupedRBs.get_group(2)['SINR(dB)'].plot(style='.')
(rttDF1_scenario['new_RTT']*1000).plot(style='.')
(cwndDF1_scenario['new_CWND']/5000000).plot(style='.')
(dataDF1_scenario['PKG_SIZE']/50).plot(style='.')

# %%
np.min(cwndDF1_scenario['new_CWND'])
# Out:
# 1400
